# %%
import numpy as np
import matplotlib.pyplot as plt

import solubility
import util

# %%
T = np.arange(0, 32.1, 0.1)
S = 35.

plt.plot(T, solubility.O2(S, T), label='solubility.O2')
plt.plot(T, solubility.N2(S, T), label='solubility.N2')

plt.legend();
plt.xlabel('T [°C]')
plt.ylabel('Solubility [µmol/kg/atm]');
